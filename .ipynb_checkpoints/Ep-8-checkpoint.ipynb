# %%
import numpy as np                   # plotting graph using numpy

# %%
x=np.linspace(-40,40,100)

# %%
x.size
# Out:
# 100

# %%
y=np.sin(x)

# %%
y.size
# Out:
# 100

# %%
import matplotlib.pyplot as plt    # for garph we use matplotlib and their sub-library(pyplot)
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
y=x*x + 5*x +10

# %%
plt.plot(x,y)
